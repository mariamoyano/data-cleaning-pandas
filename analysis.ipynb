# %%
import pandas as pd
import numpy as np
import re

# %%
df_analysis = pd.read_csv("OUTPUT/shark-attacks.csv")

# %% [markdown]
# Hipotesis: ataques por paises y por decadas, ataques mortales y no mortales

# %% [markdown]
# # ATAQUES POR DÉCADAS:

# %% [markdown]
# Ataques no mortales por decadas:

# %%
#Gráfico que representa los ataques no mortales por décadas
df_analysis.loc[df_analysis["Fatal (Y/N)"] == "N"].groupby("Decade").agg({"Fatal (Y/N)": "count"}).plot.bar()

# %%
df_analysis.loc[df_analysis["Fatal (Y/N)"] == "N"].groupby("Decade").agg({"Fatal (Y/N)": "count"})
# Out:
#         Fatal (Y/N)
# Decade
# 1740              1
# 1780              1
# 1800              4
# 1810              1
# 1820              2
# 1830              5
# 1840             15
# 1850              7
# 1860             22
# 1870             39
# 1880             41
# 1890             44
# 1900             49
# 1910             65
# 1920            110
# 1930            145
# 1940            134
# 1950            258
# 1960            378
# 1970            221
# 1980            317
# 1990            424
# 2000            801
# 2010            851

# %% [markdown]
# Ataques mortales por décadas:

# %%
#Grdf_analysis.loc[df_analysis["Fatal (Y/N)"] == "N"].groupby("Decade").agg({"Fatal (Y/N)": "count"})áfico que representa los ataques no mortales por décadas
df_analysis.loc[df_analysis["Fatal (Y/N)"] == "Y"].groupby("Decade").agg({"Fatal (Y/N)": "count"}).plot.bar()

# %%
df_analysis.loc[df_analysis["Fatal (Y/N)"] == "Y"].groupby("Decade").agg({"Fatal (Y/N)": "count"})
# Out:
#         Fatal (Y/N)
# Decade
# 1720              1
# 1730              1
# 1740              1
# 1750              2
# 1760              1
# 1770              2
# 1780              3
# 1790              2
# 1800              3
# 1810              4
# 1820              6
# 1830              8
# 1840             16
# 1850             24
# 1860             26
# 1870             25
# 1880             46
# 1890             51
# 1900             68
# 1910             55
# 1920             65
# 1930             74
# 1940             74
# 1950            107
# 1960             91
# 1970             57
# 1980             41
# 1990             77
# 2000             82
# 2010             64

# %% [markdown]
# # ATAQUES POR PAÍS

# %% [markdown]
# Ataques totales por pais

# %%
#Gráfico que representa los ataques totales por pais
df_analysis.groupby("Country").agg({"Fatal (Y/N)": "count"}).plot.bar()

# %%
df_analysis.groupby("Country").agg({"Fatal (Y/N)": "count"})
# Out:
#                   Fatal (Y/N)
# Country
# ATLANTIC OCEAN             15
# AUSTRALIA                1208
# BAHAMAS                   101
# BERMUDA                    11
# BRAZIL                    104
# COSTA RICA                 15
# CROATIA                    27
# CUBA                       41
# EGYPT                      35
# ENGLAND                    20
# FIJI                       59
# FRENCH POLYNESIA           23
# GREECE                     14
# HONG KONG                  24
# INDIA                      34
# INDONESIA                  21
# IRAN                       25
# ITALY                      55
# JAMAICA                    24
# JAPAN                      28
# MEXICO                     77
# MOZAMBIQUE                 39
# NEW CALEDONIA              52
# NEW ZEALAND               115
# PACIFIC OCEAN              15
# PANAMA                     29
# PAPUA NEW GUINEA          128
# PHILIPPINES                57
# REUNION                    58
# SOLOMON ISLANDS            28
# SOUTH AFRICA              507
# SPAIN                      33
# TONGA                      14
# USA                      2024
# VIETNAM                    13

# %%
#Gráfico que representa los ataques No mortales por pais
df_analysis.loc[df_analysis["Fatal (Y/N)"] == "N"].groupby("Country").agg({"Fatal (Y/N)": "count"}).plot.bar()

# %%
df_analysis.loc[df_analysis["Fatal (Y/N)"] == "N"].groupby("Country").agg({"Fatal (Y/N)": "count"})
# Out:
#                   Fatal (Y/N)
# Country
# ATLANTIC OCEAN              7
# AUSTRALIA                 912
# BAHAMAS                    91
# BERMUDA                    10
# BRAZIL                     64
# COSTA RICA                  7
# CROATIA                    10
# CUBA                       17
# EGYPT                      21
# ENGLAND                    16
# FIJI                       37
# FRENCH POLYNESIA           20
# GREECE                      4
# HONG KONG                   7
# INDIA                      12
# INDONESIA                   7
# IRAN                       15
# ITALY                      39
# JAMAICA                    10
# JAPAN                      16
# MEXICO                     34
# MOZAMBIQUE                 19
# NEW CALEDONIA              34
# NEW ZEALAND                91
# PACIFIC OCEAN               8
# PANAMA                     13
# PAPUA NEW GUINEA           72
# PHILIPPINES                21
# REUNION                    30
# SOLOMON ISLANDS            15
# SOUTH AFRICA              406
# SPAIN                      25
# TONGA                      10
# USA                      1824
# VIETNAM                    11

# %%
#Gráfico que representa los ataques mortales por pais
df_analysis.loc[df_analysis["Fatal (Y/N)"] == "Y"].groupby("Country").agg({"Fatal (Y/N)": "count"}).plot.bar()

# %%
df_analysis.loc[df_analysis["Fatal (Y/N)"] == "Y"].groupby("Country").agg({"Fatal (Y/N)": "count"})
# Out:
#                   Fatal (Y/N)
# Country
# ATLANTIC OCEAN              8
# AUSTRALIA                 275
# BAHAMAS                    10
# BERMUDA                     1
# BRAZIL                     38
# COSTA RICA                  8
# CROATIA                    15
# CUBA                       23
# EGYPT                      12
# ENGLAND                     4
# FIJI                       21
# FRENCH POLYNESIA            2
# GREECE                     10
# HONG KONG                  17
# INDIA                      20
# INDONESIA                  14
# IRAN                       10
# ITALY                      13
# JAMAICA                    14
# JAPAN                      12
# MEXICO                     43
# MOZAMBIQUE                 19
# NEW CALEDONIA              18
# NEW ZEALAND                23
# PACIFIC OCEAN               7
# PANAMA                     16
# PAPUA NEW GUINEA           54
# PHILIPPINES                35
# REUNION                    28
# SOLOMON ISLANDS            12
# SOUTH AFRICA               99
# SPAIN                       8
# TONGA                       4
# USA                       182
# VIETNAM                     2

# %%
# %matplotlib inline
data = df_analysis[df_analysis["Fatal (Y/N)"]].agg({"Fatal (Y/N)":["Y"]})

data.plot.bar()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-72739d3056f2> in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 2 data = df_analysis[df_analysis["Fatal (Y/N)"]].agg({"Fatal (Y/N)":["Y"]})
#       3
#       4 data.plot.bar()
#
# ~/.local/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ~/.local/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1551
#    1552         self._validate_read_indexer(
# -> 1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1554         )
#    1555         return keyarr, indexer
#
# ~/.local/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1638             if missing == len(indexer):
#    1639                 axis_name = self.obj._get_axis_name(axis)
# -> 1640                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1641
#    1642             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['N', 'N', 'N', 'N', 'N', 'N', 'Y', 'N', 'N', 'N',\n       ...\n       'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y'],\n      dtype='object', length=5073)] are in the [columns]"
